# %% [markdown]
# ## [OmniParse](https://github.com/adithya-s-k/omniparse)
# Seamlessly ingest any data and get structured, actionable output.
#
# ![OmniParse](https://raw.githubusercontent.com/adithya-s-k/omniparse/main/docs/assets/hero_image.png)
# [![GitHub Stars](https://img.shields.io/github/stars/adithya-s-k/omniparse?style=social)](https://github.com/adithya-s-k/omniparse/stargazers)
# [![GitHub Forks](https://img.shields.io/github/forks/adithya-s-k/omniparse?style=social)](https://github.com/adithya-s-k/omniparse/network/members)
# [![GitHub Issues](https://img.shields.io/github/issues/adithya-s-k/omniparse)](https://github.com/adithya-s-k/omniparse/issues)
# [![GitHub Pull Requests](https://img.shields.io/github/issues-pr/adithya-s-k/omniparse)](https://github.com/adithya-s-k/omniparse/pulls)
# [![License](https://img.shields.io/github/license/adithya-s-k/omniparse)](https://github.com/adithya-s-k/omniparse/blob/main/LICENSE)
#
#
#
# ## Features
# ✅ Completely local, no external APIs
# ✅ Supports 10+ file types
# ✅ Convert documents, multimedia, and web pages to high-quality structured markdown
# ✅ Table extraction, image extraction/captioning, audio/video transcription, web page crawling
# ✅ Easily deployable using Docker and Skypilot
# ✅ Colab friendly
#
# ### Problem Statement:
# It's challenging to process data as it comes in different shapes and sizes. OmniParse aims to be an ingestion/parsing platform where you can ingest any type of data, such as documents, images, audio, video, and web content, and get the most structured and actionable output that is GenAI (LLM) friendly.
#
# ## Coming Soon
# ⭐ Dynamic chunking and structured data extraction based on specified Schema
# 🛠️ One magic API: just feed in your file prompt what you want, and we will take care of the rest
# 🔧 Dynamic model selection and support for external APIs
# 📄 Batch processing for handling multiple files at once
# 🦙 New open-source model to replace Surya OCR and Marker
#
# **Final goal** - replace all the different models currently being used with a single MultiModel Model to parse any type of data and get the data you need
#
# 📄 - [Documentation](https://docs.cognitivelab.in/) \
# Created by [Adithya](https://x.com/adithya_s_k).
#
# | Original PDF                                                                                                                                                                               | OmniParse-API                                                                                                                                                                           | PyPDF                                                                                                                                                               |
# | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ | ------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | [![Original PDF](https://github.com/adithya-s-k/marker-api/raw/master/data/images/original\_pdf.png)](https://github.com/adithya-s-k/marker-api/blob/master/data/images/original\_pdf.png) | [![OmniParse-API](https://github.com/adithya-s-k/marker-api/raw/master/data/images/marker\_api.png)](https://github.com/adithya-s-k/marker-api/blob/master/data/images/marker\_api.png) | [![PyPDF](https://github.com/adithya-s-k/marker-api/raw/master/data/images/pypdf.png)](https://github.com/adithya-s-k/marker-api/blob/master/data/images/pypdf.png) |

# %%
## Clone the repository

# !git clone https://github.com/adithya-s-k/omniparse.git
# %cd omniparse
# %pwd
# Out:
# fatal: destination path 'omniparse' already exists and is not an empty directory.
# /content/omniparse
# '/content/omniparse'

# %%
# %cd /content/omniparse

# whisper from git (broken pinned sdist bypass)
# %pip install git+https://github.com/openai/whisper.git

# all deps EXCEPT flash-attn (needs nvcc compile, breaks/slow on Colab)
# %pip install -e . --no-deps
# %pip install \
  scikit-learn "Pillow>=10.1,<11" "pydantic>=2.4.2" pydantic-settings \
  "transformers==4.41.2" "numpy<2.0.0" python-dotenv tqdm tabulate ftfy \
  texify rapidfuzz surya-ocr filetype "regex>=2024.4.28" pdftext grpcio \
  "fastapi==0.111.1" uvicorn pypdfium2 "moviepy<2.0.0" \
  "openai-whisper" pytube beautifulsoup4 html2text \
  selenium webdriver-manager img2pdf matplotlib timm art \
  "gradio>=4.37.1,<5.0.0" nltk "marker-pdf==0.2.17" \
  python-multipart aiofiles pdf2image
# Out:
# /content/omniparse
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-ua59diux
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-ua59diux
#   Resolved https://github.com/openai/whisper.git to commit 04f449b8a437f1bbd3dba5c9f826aca972e7709a
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from openai-whisper==20250625) (10.8.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from openai-whisper==20250625) (0.60.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from openai-whisper==20250625) (1.26.4)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (from openai-whisper==20250625) (0.13.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from openai-whisper==20250625) (2.11.0+cu128)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from openai-whisper==20250625) (4.67.3)
# Requirement already satisfied: triton>=2 in /usr/local/lib/python3.12/dist-packages (from openai-whisper==20250625) (3.6.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->openai-whisper==20250625) (0.43.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from tiktoken->openai-whisper==20250625) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from tiktoken->openai-whisper==20250625) (2.32.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->openai-whisper==20250625) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (12.9.6)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper==20250625) (3.4.5)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->openai-whisper==20250625) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->openai-whisper==20250625) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->openai-whisper==20250625) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->openai-whisper==20250625) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->openai-whisper==20250625) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->openai-whisper==20250625) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->openai-whisper==20250625) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->openai-whisper==20250625) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->openai-whisper==20250625) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->openai-whisper==20250625) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->openai-whisper==20250625) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch->openai-whisper==20250625) (1.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->openai-whisper==20250625) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->openai-whisper==20250625) (2.1.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->tiktoken->openai-whisper==20250625) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->tiktoken->openai-whisper==20250625) (3.15)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->tiktoken->openai-whisper==20250625) (2.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->tiktoken->openai-whisper==20250625) (2026.5.20)
# Obtaining file:///content/omniparse
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Building wheels for collected packages: omniparse
#   Building editable for omniparse (pyproject.toml) ... done
#   Created wheel for omniparse: filename=omniparse-0.0.1-py3-none-any.whl size=18585 sha256=b8db0a360461e955a7e44ba1c3bfea68a72a5ce1ce9d9679295bb723f3d0f144
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ta_g0c0l/wheels/cf/c3/84/a1043a0cf359d712fd722f53a527a6145dd61421ef78e8d51d
# Successfully built omniparse
# Installing collected packages: omniparse
#   Attempting uninstall: omniparse
#     Found existing installation: omniparse 0.0.1
#     Uninstalling omniparse-0.0.1:
#       Successfully uninstalled omniparse-0.0.1
# Successfully installed omniparse-0.0.1
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.4.2)
# Requirement already satisfied: Pillow<11,>=10.1 in /usr/local/lib/python3.12/dist-packages (10.4.0)
# Requirement already satisfied: pydantic>=2.4.2 in /usr/local/lib/python3.12/dist-packages (2.12.3)
# Requirement already satisfied: pydantic-settings in /usr/local/lib/python3.12/dist-packages (2.14.1)
# Requirement already satisfied: transformers==4.41.2 in /usr/local/lib/python3.12/dist-packages (4.41.2)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.12/dist-packages (1.26.4)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (0.9.0)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.12/dist-packages (6.3.1)
# Requirement already satisfied: texify in /usr/local/lib/python3.12/dist-packages (0.1.10)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.12/dist-packages (3.14.5)
# Requirement already satisfied: surya-ocr in /usr/local/lib/python3.12/dist-packages (0.5.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.12/dist-packages (1.2.0)
# Requirement already satisfied: regex>=2024.4.28 in /usr/local/lib/python3.12/dist-packages (2024.11.6)
# Requirement already satisfied: pdftext in /usr/local/lib/python3.12/dist-packages (0.3.20)
# Requirement already satisfied: grpcio in /usr/local/lib/python3.12/dist-packages (1.80.0)
# Requirement already satisfied: fastapi==0.111.1 in /usr/local/lib/python3.12/dist-packages (0.111.1)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.12/dist-packages (0.47.0)
# Requirement already satisfied: pypdfium2 in /usr/local/lib/python3.12/dist-packages (4.30.0)
# Requirement already satisfied: moviepy<2.0.0 in /usr/local/lib/python3.12/dist-packages (1.0.3)
# Requirement already satisfied: openai-whisper in /usr/local/lib/python3.12/dist-packages (20250625)
# Requirement already satisfied: pytube in /usr/local/lib/python3.12/dist-packages (15.0.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: html2text in /usr/local/lib/python3.12/dist-packages (2025.4.15)
# Requirement already satisfied: selenium in /usr/local/lib/python3.12/dist-packages (4.44.0)
# Requirement already satisfied: webdriver-manager in /usr/local/lib/python3.12/dist-packages (4.1.1)
# Requirement already satisfied: img2pdf in /usr/local/lib/python3.12/dist-packages (0.6.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (1.0.27)
# Requirement already satisfied: art in /usr/local/lib/python3.12/dist-packages (6.5)
# Requirement already satisfied: gradio<5.0.0,>=4.37.1 in /usr/local/lib/python3.12/dist-packages (4.44.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: marker-pdf==0.2.17 in /usr/local/lib/python3.12/dist-packages (0.2.17)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.12/dist-packages (0.0.29)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.12/dist-packages (23.2.1)
# Requirement already satisfied: pdf2image in /usr/local/lib/python3.12/dist-packages (1.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.41.2) (3.29.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.41.2) (0.36.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.41.2) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.41.2) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.41.2) (2.32.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.12/dist-packages (from transformers==4.41.2) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.41.2) (0.7.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /usr/local/lib/python3.12/dist-packages (from fastapi==0.111.1) (0.37.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from fastapi==0.111.1) (4.15.0)
# Requirement already satisfied: fastapi-cli>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi==0.111.1) (0.0.24)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from fastapi==0.111.1) (0.28.1)
# Requirement already satisfied: jinja2>=2.11.2 in /usr/local/lib/python3.12/dist-packages (from fastapi==0.111.1) (3.1.6)
# Requirement already satisfied: email_validator>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from fastapi==0.111.1) (2.3.0)
# Requirement already satisfied: torch<3.0.0,>=2.2.2 in /usr/local/lib/python3.12/dist-packages (from marker-pdf==0.2.17) (2.11.0+cu128)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.4.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.4.2) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.4.2) (0.4.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy) (0.7.0)
# Requirement already satisfied: opencv-python<5.0.0.0,>=4.9.0.80 in /usr/local/lib/python3.12/dist-packages (from surya-ocr) (4.11.0.86)
# Requirement already satisfied: onnxruntime<2.0.0,>=1.19.2 in /usr/local/lib/python3.12/dist-packages (from pdftext) (1.26.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn) (8.4.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.12/dist-packages (from moviepy<2.0.0) (4.4.2)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.12/dist-packages (from moviepy<2.0.0) (0.1.12)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.12/dist-packages (from moviepy<2.0.0) (2.37.3)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from moviepy<2.0.0) (0.6.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (10.8.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (0.60.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (0.13.0)
# Requirement already satisfied: triton>=2 in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (3.6.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8.3)
# Requirement already satisfied: certifi>=2026.2.25 in /usr/local/lib/python3.12/dist-packages (from selenium) (2026.5.20)
# Requirement already satisfied: trio<1.0,>=0.31.0 in /usr/local/lib/python3.12/dist-packages (from selenium) (0.33.0)
# Requirement already satisfied: trio-websocket<1.0,>=0.12.2 in /usr/local/lib/python3.12/dist-packages (from selenium) (0.12.2)
# Requirement already satisfied: urllib3<3.0,>=2.6.3 in /usr/local/lib/python3.12/dist-packages (from urllib3[socks]<3.0,>=2.6.3->selenium) (2.7.0)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from selenium) (1.9.0)
# Requirement already satisfied: pikepdf in /usr/local/lib/python3.12/dist-packages (from img2pdf) (10.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from timm) (0.26.0+cu128)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio<5.0.0,>=4.37.1) (4.13.0)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio<5.0.0,>=4.37.1) (1.0.0)
# Requirement already satisfied: gradio-client==1.3.0 in /usr/local/lib/python3.12/dist-packages (from gradio<5.0.0,>=4.37.1) (1.3.0)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.12/dist-packages (from gradio<5.0.0,>=4.37.1) (6.5.2)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio<5.0.0,>=4.37.1) (2.1.5)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio<5.0.0,>=4.37.1) (3.11.9)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio<5.0.0,>=4.37.1) (2.2.2)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio<5.0.0,>=4.37.1) (0.25.1)
# Requirement already satisfied: ruff>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from gradio<5.0.0,>=4.37.1) (0.15.14)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio<5.0.0,>=4.37.1) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio<5.0.0,>=4.37.1) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio<5.0.0,>=4.37.1) (0.25.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.3.0->gradio<5.0.0,>=4.37.1) (2025.3.0)
# Requirement already satisfied: websockets<13.0,>=10.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.3.0->gradio<5.0.0,>=4.37.1) (12.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio<5.0.0,>=4.37.1) (3.15)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from email_validator>=2.0.0->fastapi==0.111.1) (2.8.0)
# Requirement already satisfied: rich-toolkit>=0.14.8 in /usr/local/lib/python3.12/dist-packages (from fastapi-cli>=0.0.2->fastapi==0.111.1) (0.20.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->fastapi==0.111.1) (1.0.9)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.2) (1.5.0)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2.0.0,>=1.19.2->pdftext) (25.12.19)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2.0.0,>=1.19.2->pdftext) (5.29.6)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio<5.0.0,>=4.37.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio<5.0.0,>=4.37.1) (2026.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.41.2) (3.4.7)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->marker-pdf==0.2.17) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->marker-pdf==0.2.17) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->marker-pdf==0.2.17) (3.6.1)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3.0.0,>=2.2.2->marker-pdf==0.2.17) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->marker-pdf==0.2.17) (12.9.6)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->marker-pdf==0.2.17) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->marker-pdf==0.2.17) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->marker-pdf==0.2.17) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->marker-pdf==0.2.17) (3.4.5)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3.0.0,>=2.2.2->marker-pdf==0.2.17) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3.0.0,>=2.2.2->marker-pdf==0.2.17) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3.0.0,>=2.2.2->marker-pdf==0.2.17) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3.0.0,>=2.2.2->marker-pdf==0.2.17) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3.0.0,>=2.2.2->marker-pdf==0.2.17) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3.0.0,>=2.2.2->marker-pdf==0.2.17) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3.0.0,>=2.2.2->marker-pdf==0.2.17) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3.0.0,>=2.2.2->marker-pdf==0.2.17) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3.0.0,>=2.2.2->marker-pdf==0.2.17) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3.0.0,>=2.2.2->marker-pdf==0.2.17) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<3.0.0,>=2.2.2->marker-pdf==0.2.17) (12.8.90)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from trio<1.0,>=0.31.0->selenium) (26.1.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.12/dist-packages (from trio<1.0,>=0.31.0->selenium) (2.4.0)
# Requirement already satisfied: outcome in /usr/local/lib/python3.12/dist-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from trio<1.0,>=0.31.0->selenium) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.12/dist-packages (from trio-websocket<1.0,>=0.12.2->selenium) (1.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio<5.0.0,>=4.37.1) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio<5.0.0,>=4.37.1) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio<5.0.0,>=4.37.1) (0.0.4)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from urllib3[socks]<3.0,>=2.6.3->selenium) (1.7.1)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0->fastapi==0.111.1) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0->fastapi==0.111.1) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0->fastapi==0.111.1) (1.2.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->openai-whisper) (0.43.0)
# Requirement already satisfied: lxml>=4.8 in /usr/local/lib/python3.12/dist-packages (from pikepdf->img2pdf) (6.1.1)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch<3.0.0,>=2.2.2->marker-pdf==0.2.17) (1.5.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio<5.0.0,>=4.37.1) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio<5.0.0,>=4.37.1) (2.20.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0.0,>=2.2.2->marker-pdf==0.2.17) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0,>=0.12->gradio<5.0.0,>=4.37.1) (0.1.2)

# %%
# %pip install transformers==4.41.2
# Out:
# Requirement already satisfied: transformers==4.41.2 in /usr/local/lib/python3.12/dist-packages (4.41.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.41.2) (3.29.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.41.2) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.41.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.41.2) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.41.2) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.41.2) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.41.2) (2.32.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.12/dist-packages (from transformers==4.41.2) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.41.2) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==4.41.2) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.2) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.2) (1.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.2) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.41.2) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.41.2) (3.15)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.41.2) (2.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.41.2) (2026.5.20)

# %%
# Update and install necessary packages
# !apt-get update && apt-get install -y --no-install-recommends \
    wget \
    curl \
    unzip \
    git \
    libgl1 \
    libglib2.0-0 \
    curl \
    gnupg2 \
    ca-certificates \
    apt-transport-https \
    software-properties-common \
    libreoffice \
    ffmpeg \
    git-lfs \
    xvfb \
    && ln -s /usr/bin/python3 /usr/bin/python \
    && curl -s https://packagecloud.io/install/repositories/github/git-lfs/script.deb.sh | bash \
    && wget -q -O - https://dl.google.com/linux/linux_signing_key.pub | apt-key add - \
    && echo "deb http://dl.google.com/linux/chrome/deb/ stable main" > /etc/apt/sources.list.d/google-chrome.list \
    && apt-get update \
    && apt install python3-packaging \
    && apt-get install -y --no-install-recommends google-chrome-stable \
    && rm -rf /var/lib/apt/lists/*

# Download and install ChromeDriver
# !CHROMEDRIVER_VERSION=$(curl -sS chromedriver.storage.googleapis.com/LATEST_RELEASE) && \
    wget -q -N https://chromedriver.storage.googleapis.com/$CHROMEDRIVER_VERSION/chromedriver_linux64.zip -P /tmp && \
    unzip -o /tmp/chromedriver_linux64.zip -d /tmp && \
    mv /tmp/chromedriver /usr/local/bin/chromedriver && \
    chmod +x /usr/local/bin/chromedriver && \
    rm /tmp/chromedriver_linux64.zip

# Set environment variables
import os
os.environ['CHROME_BIN'] = '/usr/bin/google-chrome'
os.environ['CHROMEDRIVER'] = '/usr/local/bin/chromedriver'
os.environ['DISPLAY'] = ':99'
os.environ['DBUS_SESSION_BUS_ADDRESS'] = '/dev/null'
os.environ['PYTHONUNBUFFERED'] = '1'

print("✅ Set up complete")
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://dl.google.com/linux/chrome/deb stable InRelease
# Hit:5 https://packagecloud.io/github/git-lfs/ubuntu jammy InRelease
# Hit:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:8 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,312 kB]
# Hit:13 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [7,400 kB]
# Hit:15 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 11.8 MB in 3s (3,851 kB/s)
# Reading package lists... Done
# W: http://dl.google.com/linux/chrome/deb/dists/stable/InRelease: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libgl1 is already the newest version (1.4.0-1).
# ca-certificates is already the newest version (20240203~22.04.1).
# curl is already the newest version (7.81.0-1ubuntu1.24).
# git is already the newest version (1:2.34.1-1ubuntu1.17).
# libglib2.0-0 is already the newest version (2.72.4-0ubuntu2.9).
# software-properties-common is already the newest version (0.99.22.9).
# unzip is already the newest version (6.0-26ubuntu3.2).
# wget is already the newest version (1.21.2-2ubuntu1.1).
# apt-transport-https is already the newest version (2.4.14).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# gnupg2 is already the newest version (2.2.27-3ubuntu2.5).
# libreoffice is already the newest version (1:7.3.7-0ubuntu0.22.04.11).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# The following packages will be upgraded:
#   git-lfs
# 1 upgraded, 0 newly installed, 0 to remove and 64 not upgraded.
# Need to get 8,925 kB of archives.
# After this operation, 8,723 kB of additional disk space will be used.
# Get:1 https://packagecloud.io/github/git-lfs/ubuntu jammy/main amd64 git-lfs amd64 3.7.1 [8,925 kB]
# Fetched 8,925 kB in 0s (23.2 MB/s)
# (Reading database ... 126952 files and directories currently installed.)
# Preparing to unpack .../git-lfs_3.7.1_amd64.deb ...
# Unpacking git-lfs (3.7.1) over (3.0.2-1ubuntu0.3) ...
# Setting up git-lfs (3.7.1) ...
# Git LFS initialized.
# Processing triggers for man-db (2.10.2-1) ...
# ln: failed to create symbolic link '/usr/bin/python': File exists
# Archive:  /tmp/chromedriver_linux64.zip
#   inflating: /tmp/chromedriver
#   inflating: /tmp/LICENSE.chromedriver
# ✅ Set up complete

# %%
# ===== Patch gradio_client bool-schema bug =====
import gradio_client.utils as u, inspect, re

path = u.__file__
src = open(path).read()

# guard get_type against non-dict schema
if "def get_type(schema):" in src and "isinstance(schema, bool)" not in src:
    src = src.replace(
        "def get_type(schema):",
        "def get_type(schema):\n    if not isinstance(schema, dict):\n        return 'Any'",
        1,
    )

# guard _json_schema_to_python_type entry
src = src.replace(
    "def _json_schema_to_python_type(schema: Any, defs) -> str:\n    \"\"\"Convert the json schema into a python type hint\"\"\"",
    "def _json_schema_to_python_type(schema: Any, defs) -> str:\n    \"\"\"Convert the json schema into a python type hint\"\"\"\n    if isinstance(schema, bool):\n        return 'Any'",
)

open(path, "w").write(src)
print("✅ patched gradio_client utils.py")
# Out:
# ✅ patched gradio_client utils.py

# %% [markdown]
# ### Using Cloudflare tunnels (Recommended)
# After the server is set up and cloudflare is available please go to /docs to access all the api endpoints

# %%
# !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb

import subprocess
import threading
import time
import socket
import urllib.request

def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  print("\nOmniPrase API finished loading, trying to launch cloudflared (if it gets stuck here cloudflared is having issues)\n")

  p = subprocess.Popen(["cloudflared", "tunnel", "--url", "http://127.0.0.1:{}".format(port)], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
  for line in p.stderr:
    l = line.decode()
    if "trycloudflare.com " in l:
      print("This is the URL to access OmniPrase:", l[l.find("http"):], end='')
    #print(l, end='')


threading.Thread(target=iframe_thread, daemon=True, args=(8000,)).start()

# !python server.py --host 127.0.0.1 --port 8000 --documents --media --web
# Out:
# --2026-06-03 08:07:41--  https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/cloudflare/cloudflared/releases/download/2026.5.2/cloudflared-linux-amd64.deb [following]
# --2026-06-03 08:07:41--  https://github.com/cloudflare/cloudflared/releases/download/2026.5.2/cloudflared-linux-amd64.deb
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/106867604/0ec93a74-a3bc-474a-bd4b-e852ababcbb3?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-06-03T09%3A03%3A13Z&rscd=attachment%3B+filename%3Dcloudflared-linux-amd64.deb&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-06-03T08%3A02%3A55Z&ske=2026-06-03T09%3A03%3A13Z&sks=b&skv=2018-11-09&sig=E16ipnHtLN9sY9ryb89A76gLRqAIOAmpCxGKh7OO3PQ%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4MDQ3NTg2MSwibmJmIjoxNzgwNDc0MDYxLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.H7muI28XZ4x7Kf8rUrnh-zUVIlh_4Xal1xZ_sYl7nFE&response-content-disposition=attachment%3B%20filename%3Dcloudflared-linux-amd64.deb&response-content-type=application%2Foctet-stream [following]
# --2026-06-03 08:07:41--  https://release-assets.githubusercontent.com/github-production-release-asset/106867604/0ec93a74-a3bc-474a-bd4b-e852ababcbb3?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-06-03T09%3A03%3A13Z&rscd=attachment%3B+filename%3Dcloudflared-linux-amd64.deb&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-06-03T08%3A02%3A55Z&ske=2026-06-03T09%3A03%3A13Z&sks=b&skv=2018-11-09&sig=E16ipnHtLN9sY9ryb89A76gLRqAIOAmpCxGKh7OO3PQ%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4MDQ3NTg2MSwibmJmIjoxNzgwNDc0MDYxLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.H7muI28XZ4x7Kf8rUrnh-zUVIlh_4Xal1xZ_sYl7nFE&response-content-disposition=attachment%3B%20filename%3Dcloudflared-linux-amd64.deb&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18855420 (18M) [application/octet-stream]
# Saving to: ‘cloudflared-linux-amd64.deb.1’
#
# cloudflared-linux-a 100%[===================>]  17.98M  --.-KB/s    in 0.08s
#
# 2026-06-03 08:07:41 (221 MB/s) - ‘cloudflared-linux-amd64.deb.1’ saved [18855420/18855420]
#
# (Reading database ... 126945 files and directories currently installed.)
# Preparing to unpack cloudflared-linux-amd64.deb ...
# Unpacking cloudflared (2026.5.2) over (2026.5.2) ...
# Setting up cloudflared (2026.5.2) ...
# Processing triggers for man-db (2.10.2-1) ...
# 2026-06-03 08:07:50.547098: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:294: SyntaxWarning: invalid escape sequence '\d'
#   lines_video = [l for l in lines if ' Video: ' in l and re.search('\d+x\d+', l)]
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:367: SyntaxWarning: invalid escape sequence '\d'
#   rotation_lines = [l for l in lines if 'rotate          :' in l and re.search('\d+$', l)]
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:370: SyntaxWarning: invalid escape sequence '\d'
#   match = re.search('\d+$', rotation_line)
# error: XDG_RUNTIME_DIR not set in the environment.
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
#
#
#        .88888.                      oo  888888ba
#       d8'   `8b                         88    `8b
#       88     88 88d8b.d8b. 88d888b. dP a88aaaa8P' .d8888b. 88d888b. .d8888b. .d8888b.
#       88     88 88'`88'`88 88'  `88 88  88        88'  `88 88'  `88 Y8ooooo. 88ooood8
#       Y8.   .8P 88  88  88 88    88 88  88        88.  .88 88             88 88.  ...
#        `8888P'  dP  dP  dP dP    dP dP  dP        `88888P8 dP       `88888P' `88888P'
#
#
#
# Created by Adithya S K : https://twitter.com/adithya_s_k
#
#
#
#
# [LOG] ✅ Loading OCR Model
# config.json: 100% 811/811 [00:00<00:00, 6.42MB/s]
# model.safetensors: 100% 154M/154M [00:02<00:00, 76.5MB/s]
# Loaded detection model vikp/surya_det3 on device cuda with dtype torch.float16
# preprocessor_config.json: 100% 675/675 [00:00<00:00, 6.43MB/s]
# config.json: 1.32kB [00:00, 5.35MB/s]
# model.safetensors: 100% 154M/154M [00:01<00:00, 88.2MB/s]
# Loaded detection model vikp/surya_layout3 on device cuda with dtype torch.float16
# preprocessor_config.json: 100% 373/373 [00:00<00:00, 1.85MB/s]
# config.json: 5.04kB [00:00, 19.5MB/s]
# model.safetensors: 100% 550M/550M [00:05<00:00, 95.0MB/s]
# generation_config.json: 100% 160/160 [00:00<00:00, 1.38MB/s]
# Loaded reading order model vikp/surya_order on device cuda with dtype torch.float16
# preprocessor_config.json: 100% 684/684 [00:00<00:00, 6.32MB/s]
# config.json: 8.05kB [00:00, 33.1MB/s]
# model.safetensors: 100% 941M/941M [00:14<00:00, 64.7MB/s]
# generation_config.json: 100% 163/163 [00:00<00:00, 1.02MB/s]
# Loaded recognition model vikp/surya_rec2 on device cuda with dtype torch.float16
# preprocessor_config.json: 100% 556/556 [00:00<00:00, 4.51MB/s]
# config.json: 4.92kB [00:00, 19.3MB/s]
# model.safetensors: 100% 625M/625M [00:03<00:00, 162MB/s]
# generation_config.json: 100% 191/191 [00:00<00:00, 1.92MB/s]
# Loaded texify model to cuda with torch.float16 dtype
# preprocessor_config.json: 100% 617/617 [00:00<00:00, 4.77MB/s]
# tokenizer_config.json: 4.49kB [00:00, 24.7MB/s]
# tokenizer.json: 2.14MB [00:00, 54.5MB/s]
# added_tokens.json: 18.3kB [00:00, 46.2MB/s]
# special_tokens_map.json: 100% 552/552 [00:00<00:00, 4.23MB/s]
# [LOG] ✅ Loading Vision Model
# config.json: 2.43kB [00:00, 14.7MB/s]
# configuration_florence2.py: 15.1kB [00:00, 42.8MB/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Florence-2-base:
# - configuration_florence2.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_florence2.py: 127kB [00:00, 157MB/s]
# Traceback (most recent call last):
#   File "/content/omniparse/server.py", line 88, in <module>
#     main()
#   File "/content/omniparse/server.py", line 53, in main
#     load_omnimodel(args.documents, args.media, args.web)
#   File "/content/omniparse/omniparse/__init__.py", line 51, in load_omnimodel
#     shared_state.vision_model = AutoModelForCausalLM.from_pretrained(
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/auto/auto_factory.py", line 550, in from_pretrained
#     model_class = get_class_from_dynamic_module(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/dynamic_module_utils.py", line 501, in get_class_from_dynamic_module
#     final_module = get_cached_module_file(
#                    ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/dynamic_module_utils.py", line 326, in get_cached_module_file
#     modules_needed = check_imports(resolved_module_file)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/dynamic_module_utils.py", line 181, in check_imports
#     raise ImportError(
# ImportError: This modeling file requires the following packages that were not found in your environment: flash_attn. Run `pip install flash_attn`

# %% [markdown]
# ### Forward using localtunnel

# %%
# !npm install -g localtunnel

# import subprocess
# import threading
# import time
# import socket
# import urllib.request

# def iframe_thread(port):
#   while True:
#       time.sleep(0.5)
#       sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
#       result = sock.connect_ex(('127.0.0.1', port))
#       if result == 0:
#         break
#       sock.close()
#   print("\Omniparse finished loading, trying to launch localtunnel (if it gets stuck here localtunnel is having issues)\n")

#   print("The password/enpoint ip for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
#   p = subprocess.Popen(["lt", "--port", "{}".format(port)], stdout=subprocess.PIPE)
#   for line in p.stdout:
#     print(line.decode(), end='')


# threading.Thread(target=iframe_thread, daemon=True, args=(8000,)).start()

# !python server.py --host 127.0.0.1 --port 8000 --documents --media --web
